# %%
from googleapiclient.discovery import build
from youtube_api import YouTubeDataAPI
import requests
import time

# %%
time.s

# %%
s_df = pd.read_csv('name_of_supplements.csv')
s_df
# Out:
#      Unnamed: 0                   Name  \
# 0             0         Acorus calamus
# 1             1              Adrafinil
# 2             2    Aframomum melegueta
# 3             3               Agmatine
# 4             4                Alanine
# ..          ...                    ...
# 414         414  1,3-Dimethylamylamine
# 415         415      2,4-Dinitrophenol
# 416         416                  5-HTP
# 417         417   7,8-Dihydroxyflavone
# 418         418            7-Keto DHEA
#
#                                                  a.k.a
# 0    aka Sweet Flag, Golomi, Ugragandha, Vacha, Vek...
# 1                               aka Olmifon, CRL-40028
# 2    aka Grains of Paradise, melegueta pepper, alli...
# 3    aka Clonidine-displacing substance, 4-(aminobu...
# 4                                                  NaN
# ..                                                 ...
# 414  aka 4-methylhexan-2-amine, DMAA, Dimethylamyla...
# ...

# %%
s_df['Name'][0]
# Out:
# 'Acorus calamus'

# %%
api_key = "API_KEY"

# %%
yt = YouTubeDataAPI(api_key)

# %%
youtube = build('youtube','v3',developerKey=api_key)

# %%
ssup_list = ['Milk thistle', 'Creatine', 'Curcumin', 'Omega 3',
'Testosterone Boosters','Vitamin C','Vitamin D','CoQ10',
'Multivitamin','Zinc','Probiotic','B-complex','Calcium',
'Melatonin','Vitamin K','Collagen','Coconut oil','Lutein','Nicotine',
'Ashwagandha','Maca','L-carnitine','Kombucha','Krill oil',
'Hibiscus', 'Amino acid']

# %%
len(ssup_list)
# Out:
# 26

# %%
response = youtube.search().list(part="snippet",q=s_df.Name[0],regionCode='US',\
                                 relevanceLanguage='en',order='viewCount',maxResults = 50,
                                pageToken = 'CDIQAA',type='video')
vdolist2 = response.execute()

# %%
vdolist2['items'][0]
# Out:
# {'kind': 'youtube#searchResult',
#  'etag': 'afPJQVJu8JtpQXeQWurrnQVz_z8',
#  'id': {'kind': 'youtube#video', 'videoId': 'WC7_VI1ZbAo'},
#  'snippet': {'publishedAt': '2016-01-18T14:25:03Z',
#   'channelId': 'UCdQaKIjTvbv7ctmRw75upZw',
#   'title': 'vacha Acorus Calamus Supplier &amp; Exporter rhizome, entire plant/extract',
#   'description': 'Vacha Acorus calamus Acorus calamus chemical Constituents – Acolamone, Acorenone, Acoragermacrone, Acoramone, Acorone, Cis- & trans- asarone, B-& ...',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/WC7_VI1ZbAo/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/WC7_VI1ZbAo/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/WC7_VI1ZbAo/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'Ayurvedic Treatments By Dr. Shridhar Aggarwal',
#   'liveBroadcastContent': 'none',
# ...

# %%
vdolist['items'][0]
# Out:
# {'kind': 'youtube#searchResult',
#  'etag': 'rNwwVWupSygRCsZ2YgdsZz-LJcM',
#  'id': {'kind': 'youtube#video', 'videoId': 'Tarni6mZeJg'},
#  'snippet': {'publishedAt': '2018-07-16T10:26:35Z',
#   'channelId': 'UCDISsX4LNJ5lxyleDDF2P6w',
#   'title': 'உங்கள் வீட்டில் கண்டிப்பாக இருக்கவேண்டிய வசம்பு  Acorus calamus',
#   'description': 'வசம்பு, வசம்பு மருத்துவ பயன்கள், வசம்பு செடி, வசம்பு நன்மைகள், வசம்பு வளையல், வசம்பு ...',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Tarni6mZeJg/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/Tarni6mZeJg/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/Tarni6mZeJg/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'Tamil 4 Health',
#   'liveBroadcastContent': 'none',
#   'publishTime': '2018-07-16T10:26:35Z'}}

# %%
#video meta data
def videodata (idx,id_list):
    api_key = "AIzaSyBVLDM5pj-J1r6QkqNOntFEzQRHoUWgcrw"
    yt = YouTubeDataAPI(api_key)
    category = []
    #desc = []
    view = []
    like = []
    dislike = []
    comment = []
    for data in id_list:
        category.append(yt.get_video_metadata(data)['video_category'])
        #desc.append(yt.get_video_metadata(data)['video_description'].strip())
        view.append(yt.get_video_metadata(data)['video_view_count'])
        like.append(yt.get_video_metadata(data)['video_like_count'])
        dislike.append(yt.get_video_metadata(data)['video_dislike_count'])
        comment.append(yt.get_video_metadata(data)['video_comment_count'])
    df = pd.DataFrame({
    'category':category,
    #'description':desc,
    'view_count':view,
    'like_count':like,
    'dislike_count':dislike,
    'com_count':comment
    })
    return df

# %%
dfs = []
for idx in range(2):
    response = youtube.search().list(part="snippet",q=s_df.Name[idx],regionCode='US',\
                                 relevanceLanguage='en',order='viewCount',maxResults=50,
                                    type='video')
    vdolist = response.execute()
    id_list = []
    for idx in range(len(vdolist['items'])):
        id_list.append(vdolist['items'][idx]['id']['videoId'])
    dfs.append(videodata(idx,id_list))
pd.concat(dfs)
# Out:
#       category view_count like_count dislike_count com_count
# Boron       24      86561        922            67        15
# Boron       26      64169        689            51       186
# Boron       27      53325        570            31        19
# Boron       22      42276        398            30        19
# Boron       28      31452        625            37       108
# ...        ...        ...        ...           ...       ...
# Boron       22        321          2             4         0
# Boron       22        315          0             0         0
# Boron       22        271          1             5         0
# Boron       22        233          2             1      None
# Boron       22        231          5             0         0
#
# [100 rows x 5 columns]

# %%
dfs
# Out:
# [      category view_count like_count dislike_count com_count
#  Boron       24      86561        922            67        15
#  Boron       26      64169        689            51       186
#  Boron       27      53325        570            31        19
#  Boron       22      42276        398            30        19
#  Boron       28      31452        625            37       108
#  Boron       27      30402        309            22         2
#  Boron       29      30099        319            25        29
#  Boron       26      23021        185            13        47
#  Boron       22      21003        340             6        17
#  Boron       27      20616        223             3         7
#  Boron       26      17961        294            10         7
#  Boron       22      14405        109             8        10
#  Boron       26      12954         31             5         4
#  Boron       27      12843        214             1        18
# ...
